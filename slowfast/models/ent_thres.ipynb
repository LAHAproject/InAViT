# %%
import matplotlib.pyplot as plt
import numpy as np

base_entropy =  6.501
entropies = []
decay_rate = 5
x = np.linspace(0, 50, 50)
for i in range(50):
    base_entropy = decay_rate*np.exp(-.1*(i+1))
    entropies.append(base_entropy)

plt.plot(x,entropies)
