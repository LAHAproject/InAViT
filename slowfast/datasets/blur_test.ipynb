# %%
from PIL import Image
from PIL import ImageDraw
from PIL import ImageFilter

def rounded_rectangle(draw, xy, rad, fill=None):
    x0, y0, x1, y1 = xy
    draw.rectangle([ (x0, y0 + rad), (x1, y1 - rad) ], fill=fill)
    draw.rectangle([ (x0 + rad, y0), (x1 - rad, y1) ], fill=fill)
    draw.pieslice([ (x0, y0), (x0 + rad * 2, y0 + rad * 2) ], 180, 270, fill=fill)
    draw.pieslice([ (x1 - rad * 2, y1 - rad * 2), (x1, y1) ], 0, 90, fill=fill)
    draw.pieslice([ (x0, y1 - rad * 2), (x0 + rad * 2, y1) ], 90, 180, fill=fill)
    draw.pieslice([ (x1 - rad * 2, y0), (x1, y0 + rad * 2) ], 270, 360, fill=fill)

# %%
# Open an image
im = Image.open('/data/dataset/epic100_60fpsvideos_handobj_masks/frames/P01/rgb_frames/P01_01/frame_0000001000.jpg')

# Create rounded rectangle mask
mask = Image.new('L', im.size, 0)
draw = ImageDraw.Draw(mask)
rounded_rectangle(draw, (im.size[0]//4, im.size[1]//4, im.size[0]//4*3, im.size[1]//4*3), rad=52, fill=255)

# Blur image
blurred = im.filter(ImageFilter.GaussianBlur(20))

# Paste blurred region and save result
im.paste(blurred, mask=mask)

display(im)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=456x256 at 0x7F3F0CA81A30>

# %%
rounded_rectangle(draw, (im.size[0]//4+100, im.size[1]//4+100, im.size[0]//4*3, im.size[1]//4*3), rad=52, fill=255)

# Blur image
blurred = im.filter(ImageFilter.GaussianBlur(20))

# Paste blurred region and save result
im.paste(blurred, mask=mask)

display(im)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=456x256 at 0x7F3F0CA81A30>

# %%
rounded_rectangle(draw, (im.size[0]//4-100, im.size[1]//4-100, im.size[0]//4*3, im.size[1]//4*3), rad=52, fill=255)

# Blur image
blurred = im.filter(ImageFilter.GaussianBlur(20))

# Paste blurred region and save result
im.paste(blurred, mask=mask)

display(im)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=456x256 at 0x7F3F0CA81A30>

# %%
rounded_rectangle(draw, (im.size[0]//4-150, im.size[1]//4-100, im.size[0]//4*3, im.size[1]//4*3), rad=52, fill=255)

# Blur image
blurred = im.filter(ImageFilter.GaussianBlur(20))

# Paste blurred region and save result
im.paste(blurred, mask=mask)

display(im)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=456x256 at 0x7F3F0CA81A30>
